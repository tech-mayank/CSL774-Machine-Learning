# %%
import pandas as pd
import numpy as np;
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

# %%
df = pd.read_csv("complaint.csv")

# %%
df
# Out:
#      Ticket #                                 Customer Complaint        Date  \
# 0      250635                              Cable Internet Speeds  22-04-2015
# 1      223441       Payment disappear - service got disconnected  04-08-2015
# 2      242732                                  Speed and Service  18-04-2015
# 3      277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4      307175                 not working and no service to boot  26-05-2015
# ...       ...                                                ...         ...
# 2072   338192    Speed throttling, speeds not at promised output  06-12-2015
# 2073   213550                               Service Availability  04-02-2015
# 2074   318775                 Monthly Billing for Returned Modem  06-02-2015
# 2075   331188                            complaint about comcast  06-09-2015
# 2076   360489                    Extremely unsatisfied  customer  23-06-2015
#
#      Date_month_year         Time        Received Via        City     State  \
# 0          22-Apr-15   3:53:50 PM  Customer Care Call    Abingdon  Maryland
# 1          04-Aug-15  10:22:56 AM            Internet     Acworth   Georgia
# 2          18-Apr-15   9:55:47 AM            Internet     Acworth   Georgia
# 3          05-Jul-15  11:59:35 AM            Internet     Acworth   Georgia
# 4          26-May-15   1:25:26 PM            Internet     Acworth   Georgia
# ...              ...          ...                 ...         ...       ...
# 2072       06-Dec-15   6:35:59 PM  Customer Care Call   Yorkville  Illinois
# 2073       04-Feb-15   9:13:18 AM  Customer Care Call  Youngstown   Florida
# 2074       06-Feb-15   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan
# 2075       06-Sep-15   5:28:41 PM            Internet   Ypsilanti  Michigan
# 2076       23-Jun-15  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan
#
#       Zip code  Status Filing on Behalf of Someone
# 0        21009  Closed                          No
# 1        30102  Closed                          No
# 2        30101  Closed                         Yes
# 3        30101    Open                         Yes
# 4        30101  Solved                          No
# ...        ...     ...                         ...
# 2072     60560    Open                         Yes
# 2073     32466  Closed                          No
# 2074     48197  Solved                          No
# 2075     48197  Solved                          No
# 2076     48197  Solved                          No
#
# [2077 rows x 11 columns]

# %%
df["Date_month_year"]
# Out:
# 0       22-Apr-15
# 1       04-Aug-15
# 2       18-Apr-15
# 3       05-Jul-15
# 4       26-May-15
#           ...
# 2072    06-Dec-15
# 2073    04-Feb-15
# 2074    06-Feb-15
# 2075    06-Sep-15
# 2076    23-Jun-15
# Name: Date_month_year, Length: 2077, dtype: object

# %%
df['month'] = pd.DatetimeIndex(df['Date_month_year']).month

# %%
df.head(20)
# Out:
#    Ticket #                                 Customer Complaint        Date  \
# 0    250635                              Cable Internet Speeds  22-04-2015
# 1    223441       Payment disappear - service got disconnected  04-08-2015
# 2    242732                                  Speed and Service  18-04-2015
# 3    277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4    307175                 not working and no service to boot  26-05-2015
# 5    338519  ISP Charging for arbitrary data limits with ov...  06-12-2015
# 6    361148      Throttling service and unreasonable data caps  24-06-2015
# 7    359792   refuses to help troubleshoot and correct my s...  23-06-2015
# 8    318072                                   extended outages  06-01-2015
# 9    371214   Raising Prices and Not Being Available To Ask...  28-06-2015
# 10   255938  Billing after service was asked to be disconne...  24-04-2015
# 11   276409      YAHOO FAILURE TO RESTORE EMAIL SEARCH FEATURE  05-06-2015
# 12   339282   Violating Open Internet Rules by Blocking HBO...  13-06-2015
# 13   360178                                     Internet speed  23-06-2015
# 14   376268                   Internet Disconnects Every Night  30-06-2015
# 15   370137                                 Internet complaint  27-06-2015
# 16   363695                    Internet Availability and Speed  24-06-2015
# 17   238694   owes me $65 and claims I need to return equip...  16-04-2015
# 18   230876                          Horrible Internet Service  04-11-2015
# 19   318725  Failure to provide services that I am billed for.  06-02-2015
#
#    Date_month_year         Time        Received Via         City       State  \
# 0        22-Apr-15   3:53:50 PM  Customer Care Call     Abingdon    Maryland
# 1        04-Aug-15  10:22:56 AM            Internet      Acworth     Georgia
# 2        18-Apr-15   9:55:47 AM            Internet      Acworth     Georgia
# 3        05-Jul-15  11:59:35 AM            Internet      Acworth     Georgia
# 4        26-May-15   1:25:26 PM            Internet      Acworth     Georgia
# 5        06-Dec-15   9:59:40 PM            Internet      Acworth     Georgia
# 6        24-Jun-15  10:13:55 AM  Customer Care Call      Acworth     Georgia
# 7        23-Jun-15   6:56:14 PM            Internet       Adrian    Michigan
# 8        06-Jan-15  11:46:30 PM  Customer Care Call      Alameda  California
# 9        28-Jun-15   6:46:31 PM  Customer Care Call      Alameda  California
# 10       24-Apr-15   4:40:36 PM            Internet  Albuquerque  New Mexico
# 11       05-Jun-15   3:09:49 PM  Customer Care Call  Albuquerque  New Mexico
# 12       13-Jun-15   4:03:18 PM            Internet  Albuquerque  New Mexico
# 13       23-Jun-15   9:23:23 PM            Internet  Albuquerque  New Mexico
# 14       30-Jun-15  10:30:02 PM  Customer Care Call  Albuquerque  New Mexico
# 15       27-Jun-15   3:25:03 PM  Customer Care Call  Albuquerqur  New Mexico
# 16       24-Jun-15  11:47:33 PM  Customer Care Call   Alexandria     Indiana
# 17       16-Apr-15  10:04:57 AM            Internet   Alexandria    Virginia
# 18       04-Nov-15   7:48:05 PM  Customer Care Call   Alexandria    Virginia
# 19       06-Feb-15   1:03:52 PM  Customer Care Call   Alexandria    Virginia
#
#     Zip code   Status Filing on Behalf of Someone  month
# 0      21009   Closed                          No      4
# 1      30102   Closed                          No      8
# 2      30101   Closed                         Yes      4
# 3      30101     Open                         Yes      7
# 4      30101   Solved                          No      5
# 5      30101   Solved                          No     12
# 6      30101  Pending                          No      6
# 7      49221   Solved                          No      6
# 8      94502   Closed                          No      1
# 9      94501     Open                         Yes      6
# 10     87106   Closed                          No      4
# 11     87109   Closed                          No      6
# 12     87105     Open                         Yes      6
# 13     87113   Solved                          No      6
# 14     87116   Solved                          No      6
# 15     87102  Pending                          No      6
# 16     46001   Solved                          No      6
# 17     22304   Closed                          No      4
# 18     22305   Closed                          No     11
# 19     22314   Closed                          No      2

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint        Date  \
# 0   250635                              Cable Internet Speeds  22-04-2015
# 1   223441       Payment disappear - service got disconnected  04-08-2015
# 2   242732                                  Speed and Service  18-04-2015
# 3   277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4   307175                 not working and no service to boot  26-05-2015
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone  month
# 0     21009  Closed                          No      4
# 1     30102  Closed                          No      8
# 2     30101  Closed                         Yes      4
# 3     30101    Open                         Yes      7
# 4     30101  Solved                          No      5

# %%
df["Received Via"].unique()
# Out:
# array(['Customer Care Call', 'Internet'], dtype=object)

# %%
df["month"].value_counts()
# Out:
# 6     984
# 4     351
# 5     297
# 8      61
# 12     59
# 2      54
# 1      52
# 9      51
# 10     47
# 7      44
# 3      42
# 11     35
# Name: month, dtype: int64

# %%
X = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
Y = [52,54,42,351,297,984,44,61,51,47,35,59]
fig = plt.figure(figsize = (12, 8)) 
  
# creating the bar plot 
plt.bar(X, Y, color ='maroon',  
        width = 0.8) 
  
plt.xlabel("Months") 
plt.ylabel("No. of Complaints") 
plt.title("Monthly trend in registered complaints") 
plt.show()

# %%
df.head
# Out:
# <bound method NDFrame.head of      Ticket #                                 Customer Complaint        Date  \
# 0      250635                              Cable Internet Speeds  22-04-2015
# 1      223441       Payment disappear - service got disconnected  04-08-2015
# 2      242732                                  Speed and Service  18-04-2015
# 3      277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4      307175                 not working and no service to boot  26-05-2015
# ...       ...                                                ...         ...
# 2072   338192    Speed throttling, speeds not at promised output  06-12-2015
# 2073   213550                               Service Availability  04-02-2015
# 2074   318775                 Monthly Billing for Returned Modem  06-02-2015
# 2075   331188                            complaint about comcast  06-09-2015
# 2076   360489                    Extremely unsatisfied  customer  23-06-2015
#
#      Date_month_year         Time        Received Via        City     State  \
# 0          22-Apr-15   3:53:50 PM  Customer Care Call    Abingdon  Maryland
# 1          04-Aug-15  10:22:56 AM            Internet     Acworth   Georgia
# 2          18-Apr-15   9:55:47 AM            Internet     Acworth   Georgia
# 3          05-Jul-15  11:59:35 AM            Internet     Acworth   Georgia
# 4          26-May-15   1:25:26 PM            Internet     Acworth   Georgia
# ...              ...          ...                 ...         ...       ...
# 2072       06-Dec-15   6:35:59 PM  Customer Care Call   Yorkville  Illinois
# 2073       04-Feb-15   9:13:18 AM  Customer Care Call  Youngstown   Florida
# 2074       06-Feb-15   1:24:39 PM  Customer Care Call   Ypsilanti  Michigan
# 2075       06-Sep-15   5:28:41 PM            Internet   Ypsilanti  Michigan
# 2076       23-Jun-15  11:13:30 PM  Customer Care Call   Ypsilanti  Michigan
#
#       Zip code  Status Filing on Behalf of Someone  month
# 0        21009  Closed                          No      4
# 1        30102  Closed                          No      8
# 2        30101  Closed                         Yes      4
# 3        30101    Open                         Yes      7
# 4        30101  Solved                          No      5
# ...        ...     ...                         ...    ...
# 2072     60560    Open                         Yes     12
# 2073     32466  Closed                          No      2
# 2074     48197  Solved                          No      2
# 2075     48197  Solved                          No      9
# 2076     48197  Solved                          No      6
#
# [2077 rows x 12 columns]>

# %%
df["State"].nunique()
# Out:
# 42

# %%
df["State"].unique()
# Out:
# array(['Maryland', 'Georgia', 'Michigan', 'California', 'New Mexico',
#        'Indiana', 'Virginia', 'Illinois', 'Pennsylvania', 'Oregon',
#        'Massachusetts', 'New Hampshire', 'Minnesota', 'Tennessee',
#        'Florida', 'Alabama', 'Washington', 'Colorado', 'Texas',
#        'New York', 'New Jersey', 'Maine', 'West Virginia', 'Montana',
#        'Mississippi', 'Connecticut', 'Vermont', 'Kentucky',
#        'South Carolina', 'Ohio', 'Utah', 'Delaware', 'Missouri',
#        'Arkansas', 'Nevada', 'Louisiana', 'Kansas', 'Arizona',
#        'North Carolina', 'District Of Columbia', 'District of Columbia',
#        'Iowa'], dtype=object)

# %%
df["Status"].unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint        Date  \
# 0   250635                              Cable Internet Speeds  22-04-2015
# 1   223441       Payment disappear - service got disconnected  04-08-2015
# 2   242732                                  Speed and Service  18-04-2015
# 3   277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4   307175                 not working and no service to boot  26-05-2015
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone  month
# 0     21009  Closed                          No      4
# 1     30102  Closed                          No      8
# 2     30101  Closed                         Yes      4
# 3     30101    Open                         Yes      7
# 4     30101  Solved                          No      5

# %%
closed = []
country_closed = []
Open = []
country_open = []
solved = []
country_solved = []
pending = []
country_pending = []
res = {}
unres = {}
total = {}
for i in df["State"]:
    res[i] = 0
    unres[i] = 0
    total[i] = 0
cnt = 0
for i, g in df.groupby(['State','Status']):
    if(i[1] == "Closed"):
        closed.append(len(g))
        res[i[0]] += len(g)
        total[i[0]] += len(g)
        country_closed.append(i[0])
    if(i[1] == "Open"):
        Open.append(len(g))
        unres[i[0]] += len(g)
        total[i[0]] += len(g)
        country_open.append(i[0])
    if(i[1] == "Solved"):
        solved.append(len(g))
        res[i[0]] += len(g)
        total[i[0]] += len(g)
        country_solved.append(i[0])
    if(i[1] == "Pending"):
        pending.append(len(g))
        unres[i[0]] += len(g)
        total[i[0]] += len(g)
        country_pending.append(i[0])

# %%
fig = plt.figure(figsize = (80, 30)) 
  
# creating the bar plot 
plt.bar(country_closed, closed, color ='green',  
        width = 0.8) 
plt.yticks(fontsize = 60)
plt.xticks(rotation = 60,fontsize = 40) 
plt.xlabel("States",fontsize = 40) 
plt.ylabel("No. of Closed Complaints",fontsize = 40) 
plt.title("States vs No. of closed complaints",fontsize = 80) 
plt.show()

# %%
fig = plt.figure(figsize = (80, 30)) 
  
# creating the bar plot 
plt.bar(country_open, Open, color ='blue',  
        width = 0.8) 
plt.yticks(fontsize = 60)
plt.xticks(rotation = 60,fontsize = 40) 
plt.xlabel("States",fontsize = 40) 
plt.ylabel("No. of Closed Complaints",fontsize = 40) 
plt.title("States vs No. of closed complaints",fontsize = 80) 
plt.show()

# %%
fig = plt.figure(figsize = (80, 30)) 
  
# creating the bar plot 
plt.bar(country_solved, solved, color ='red',  
        width = 0.8) 
plt.yticks(fontsize = 60)
plt.xticks(rotation = 60,fontsize = 40) 
plt.xlabel("States",fontsize = 40) 
plt.ylabel("No. of Closed Complaints",fontsize = 40) 
plt.title("States vs No. of closed complaints",fontsize = 80) 
plt.show()

# %%
fig = plt.figure(figsize = (80, 30)) 
  
# creating the bar plot 
plt.bar(country_pending, pending, color ='pink',  
        width = 0.8) 
plt.yticks(fontsize = 60)
plt.xticks(rotation = 60,fontsize = 40) 
plt.xlabel("States",fontsize = 40) 
plt.ylabel("No. of Closed Complaints",fontsize = 40) 
plt.title("States vs No. of closed complaints",fontsize = 80) 
plt.show()

# %%
df["State"].value_counts()
# Out:
# Georgia                 264
# Florida                 226
# California              210
# Illinois                147
# Tennessee               137
# Pennsylvania            120
# Michigan                106
# Washington               92
# Colorado                 75
# Maryland                 71
# New Jersey               70
# Texas                    69
# Virginia                 56
# Indiana                  55
# Massachusetts            55
# Oregon                   45
# Mississippi              38
# Minnesota                29
# Alabama                  26
# Utah                     21
# Arizona                  20
# South Carolina           18
# District Of Columbia     16
# New Mexico               15
# Louisiana                13
# Connecticut              12
# New Hampshire            11
# Delaware                 11
# West Virginia            10
# Kentucky                  7
# New York                  6
# Arkansas                  5
# Maine                     5
# Ohio                      3
# Vermont                   3
# Missouri                  3
# North Carolina            2
# Iowa                      1
# Nevada                    1
# Montana                   1
# Kansas                    1
# District of Columbia      1
# Name: State, dtype: int64

# %% [markdown]
# ## Maximum complaints are registered in "GEORGIA" and minimum complaints i.e only 1 is registered in "Kansas","District of Columbia", "lowa", "Nevada", "Montana".

# %%
df2 = df[df["Status"] != "Closed"]

# %%
df2
# Out:
#      Ticket #                                 Customer Complaint        Date  \
# 3      277946   Imposed a New Usage Cap of 300GB that punishe...  05-07-2015
# 4      307175                 not working and no service to boot  26-05-2015
# 5      338519  ISP Charging for arbitrary data limits with ov...  06-12-2015
# 6      361148      Throttling service and unreasonable data caps  24-06-2015
# 7      359792   refuses to help troubleshoot and correct my s...  23-06-2015
# ...       ...                                                ...         ...
# 2070   363852                         High Internet & Cable Bill  25-06-2015
# 2072   338192    Speed throttling, speeds not at promised output  06-12-2015
# 2074   318775                 Monthly Billing for Returned Modem  06-02-2015
# 2075   331188                            complaint about comcast  06-09-2015
# 2076   360489                    Extremely unsatisfied  customer  23-06-2015
#
#      Date_month_year         Time        Received Via       City  \
# 3          05-Jul-15  11:59:35 AM            Internet    Acworth
# 4          26-May-15   1:25:26 PM            Internet    Acworth
# 5          06-Dec-15   9:59:40 PM            Internet    Acworth
# 6          24-Jun-15  10:13:55 AM  Customer Care Call    Acworth
# 7          23-Jun-15   6:56:14 PM            Internet     Adrian
# ...              ...          ...                 ...        ...
# 2070       25-Jun-15   7:17:21 AM  Customer Care Call       York
# 2072       06-Dec-15   6:35:59 PM  Customer Care Call  Yorkville
# 2074       06-Feb-15   1:24:39 PM  Customer Care Call  Ypsilanti
# 2075       06-Sep-15   5:28:41 PM            Internet  Ypsilanti
# 2076       23-Jun-15  11:13:30 PM  Customer Care Call  Ypsilanti
#
#              State  Zip code   Status Filing on Behalf of Someone  month
# 3          Georgia     30101     Open                         Yes      7
# 4          Georgia     30101   Solved                          No      5
# 5          Georgia     30101   Solved                          No     12
# 6          Georgia     30101  Pending                          No      6
# 7         Michigan     49221   Solved                          No      6
# ...            ...       ...      ...                         ...    ...
# 2070  Pennsylvania     17404   Solved                         Yes      6
# 2072      Illinois     60560     Open                         Yes     12
# 2074      Michigan     48197   Solved                          No      2
# 2075      Michigan     48197   Solved                          No      9
# 2076      Michigan     48197   Solved                          No      6
#
# [1391 rows x 12 columns]

# %%
df2["State"].value_counts()
# Out:
# Georgia                 190
# California              141
# Florida                 131
# Tennessee               100
# Illinois                 98
# Pennsylvania             70
# Michigan                 66
# Washington               58
# Colorado                 54
# Texas                    49
# New Jersey               48
# Maryland                 48
# Indiana                  41
# Oregon                   36
# Virginia                 35
# Massachusetts            33
# Mississippi              30
# Minnesota                21
# Alabama                  18
# Utah                     14
# Arizona                  14
# South Carolina           11
# District Of Columbia     11
# New Mexico               10
# Delaware                 10
# Connecticut               9
# Louisiana                 8
# New Hampshire             7
# Kentucky                  6
# West Virginia             4
# New York                  4
# Maine                     4
# Arkansas                  4
# Vermont                   3
# District of Columbia      1
# Missouri                  1
# Iowa                      1
# Ohio                      1
# Kansas                    1
# Name: State, dtype: int64

# %%
print(res)
# Out:
# {'Maryland': 60, 'Georgia': 187, 'Michigan': 85, 'California': 151, 'New Mexico': 11, 'Indiana': 47, 'Virginia': 46, 'Illinois': 120, 'Pennsylvania': 101, 'Oregon': 34, 'Massachusetts': 45, 'New Hampshire': 8, 'Minnesota': 25, 'Tennessee': 92, 'Florida': 188, 'Alabama': 17, 'Washington': 72, 'Colorado': 53, 'Texas': 48, 'New York': 6, 'New Jersey': 51, 'Maine': 3, 'West Virginia': 8, 'Montana': 1, 'Mississippi': 23, 'Connecticut': 9, 'Vermont': 2, 'Kentucky': 4, 'South Carolina': 15, 'Ohio': 3, 'Utah': 15, 'Delaware': 7, 'Missouri': 3, 'Arkansas': 5, 'Nevada': 1, 'Louisiana': 12, 'Kansas': 0, 'Arizona': 14, 'North Carolina': 2, 'District Of Columbia': 14, 'District of Columbia': 1, 'Iowa': 1}

# %%
print(unres)
# Out:
# {'Maryland': 11, 'Georgia': 77, 'Michigan': 21, 'California': 59, 'New Mexico': 4, 'Indiana': 8, 'Virginia': 10, 'Illinois': 27, 'Pennsylvania': 19, 'Oregon': 11, 'Massachusetts': 10, 'New Hampshire': 3, 'Minnesota': 4, 'Tennessee': 45, 'Florida': 38, 'Alabama': 9, 'Washington': 20, 'Colorado': 22, 'Texas': 21, 'New York': 0, 'New Jersey': 19, 'Maine': 2, 'West Virginia': 2, 'Montana': 0, 'Mississippi': 15, 'Connecticut': 3, 'Vermont': 1, 'Kentucky': 3, 'South Carolina': 3, 'Ohio': 0, 'Utah': 6, 'Delaware': 4, 'Missouri': 0, 'Arkansas': 0, 'Nevada': 0, 'Louisiana': 1, 'Kansas': 1, 'Arizona': 6, 'North Carolina': 0, 'District Of Columbia': 2, 'District of Columbia': 0, 'Iowa': 0}

# %%
print(total)
# Out:
# {'Maryland': 71, 'Georgia': 264, 'Michigan': 106, 'California': 210, 'New Mexico': 15, 'Indiana': 55, 'Virginia': 56, 'Illinois': 147, 'Pennsylvania': 120, 'Oregon': 45, 'Massachusetts': 55, 'New Hampshire': 11, 'Minnesota': 29, 'Tennessee': 137, 'Florida': 226, 'Alabama': 26, 'Washington': 92, 'Colorado': 75, 'Texas': 69, 'New York': 6, 'New Jersey': 70, 'Maine': 5, 'West Virginia': 10, 'Montana': 1, 'Mississippi': 38, 'Connecticut': 12, 'Vermont': 3, 'Kentucky': 7, 'South Carolina': 18, 'Ohio': 3, 'Utah': 21, 'Delaware': 11, 'Missouri': 3, 'Arkansas': 5, 'Nevada': 1, 'Louisiana': 13, 'Kansas': 1, 'Arizona': 20, 'North Carolina': 2, 'District Of Columbia': 16, 'District of Columbia': 1, 'Iowa': 1}

# %%
res_percentage = {}
unres_percentage = {}
for i in df["State"]:
    res_percentage[i] = 0
    unres_percentage[i] = 0
for j in res.items():
    res_percentage[j[0]] = (res[j[0]]/total[j[0]])*100
for k in unres.items():
    unres_percentage[k[0]] = (unres[k[0]]/total[k[0]])*100

# %%
print(res_percentage)
# Out:
# {'Maryland': 84.50704225352112, 'Georgia': 70.83333333333334, 'Michigan': 80.18867924528303, 'California': 71.9047619047619, 'New Mexico': 73.33333333333333, 'Indiana': 85.45454545454545, 'Virginia': 82.14285714285714, 'Illinois': 81.63265306122449, 'Pennsylvania': 84.16666666666667, 'Oregon': 75.55555555555556, 'Massachusetts': 81.81818181818183, 'New Hampshire': 72.72727272727273, 'Minnesota': 86.20689655172413, 'Tennessee': 67.15328467153284, 'Florida': 83.1858407079646, 'Alabama': 65.38461538461539, 'Washington': 78.26086956521739, 'Colorado': 70.66666666666667, 'Texas': 69.56521739130434, 'New York': 100.0, 'New Jersey': 72.85714285714285, 'Maine': 60.0, 'West Virginia': 80.0, 'Montana': 100.0, 'Mississippi': 60.526315789473685, 'Connecticut': 75.0, 'Vermont': 66.66666666666666, 'Kentucky': 57.14285714285714, 'South Carolina': 83.33333333333334, 'Ohio': 100.0, 'Utah': 71.42857142857143, 'Delaware': 63.63636363636363, 'Missouri': 100.0, 'Arkansas': 100.0, 'Nevada': 100.0, 'Louisiana': 92.3076923076923, 'Kansas': 0.0, 'Arizona': 70.0, 'North Carolina': 100.0, 'District Of Columbia': 87.5, 'District of Columbia': 100.0, 'Iowa': 100.0}

# %%
print(unres_percentage)
# Out:
# {'Maryland': 15.492957746478872, 'Georgia': 29.166666666666668, 'Michigan': 19.81132075471698, 'California': 28.095238095238095, 'New Mexico': 26.666666666666668, 'Indiana': 14.545454545454545, 'Virginia': 17.857142857142858, 'Illinois': 18.367346938775512, 'Pennsylvania': 15.833333333333332, 'Oregon': 24.444444444444443, 'Massachusetts': 18.181818181818183, 'New Hampshire': 27.27272727272727, 'Minnesota': 13.793103448275861, 'Tennessee': 32.846715328467155, 'Florida': 16.8141592920354, 'Alabama': 34.61538461538461, 'Washington': 21.73913043478261, 'Colorado': 29.333333333333332, 'Texas': 30.434782608695656, 'New York': 0.0, 'New Jersey': 27.142857142857142, 'Maine': 40.0, 'West Virginia': 20.0, 'Montana': 0.0, 'Mississippi': 39.473684210526315, 'Connecticut': 25.0, 'Vermont': 33.33333333333333, 'Kentucky': 42.857142857142854, 'South Carolina': 16.666666666666664, 'Ohio': 0.0, 'Utah': 28.57142857142857, 'Delaware': 36.36363636363637, 'Missouri': 0.0, 'Arkansas': 0.0, 'Nevada': 0.0, 'Louisiana': 7.6923076923076925, 'Kansas': 100.0, 'Arizona': 30.0, 'North Carolina': 0.0, 'District Of Columbia': 12.5, 'District of Columbia': 0.0, 'Iowa': 0.0}

# %% [markdown]
# ## countries having highest percentage of unresolved complaints:
# ### 1. Kansas (100%)
# ### 2. Tennessee (32.84%)
#
# ## countries having lowest percentage of unresolved complaints:
# ### 1. Iowa, DOC, North Carolina, Nevada, Arkansas, Missouri, Ohio, Montana, New York  (0%)

# %%
import nltk

# %%
data = ""
for i in df["Customer Complaint"]:
    data = data + i + " "

# %%
data
# Out:
# ' Cable Internet Speeds Payment disappear - service got disconnected Speed and Service  Imposed a New Usage Cap of 300GB that punishes streaming.  not working and no service to boot ISP Charging for arbitrary data limits with overage fees Throttling service and unreasonable data caps  refuses to help troubleshoot and correct my service.  extended outages  Raising Prices and Not Being Available To Ask Why Billing after service was asked to be disconnected YAHOO FAILURE TO RESTORE EMAIL SEARCH FEATURE  Violating Open Internet Rules by Blocking HBO Go Access on Sony Consoles Internet speed Internet Disconnects Every Night Internet complaint Internet Availability and Speed  owes me $65 and claims I need to return equipment I never had Horrible Internet Service Failure to provide services that I am billed for. Internet out all the time but they have a monopoly horrible cable service and customer service Speed  monopoly bundling practices bait and switch  Customer Service Unable to reach a  agent for internet and billing issues. Wifi internet not working as well  data caps  Internet Data Cap XFINITY Movers Edge program  Data Internet Usage  not refunding my credit No Service INTERNET , BILLING AND SERVIE ISSUES  blocking DirecTv signals pmts Slow Internet Speed not getting what I am paying for with internet  bandwidth every evening drops to 10% of what is promised to our business isp dishonest about speeds Deceptive sales- change in billing amount etc.  Billing Dispute  Billing and Service Issues Cable prices rising service issues HBO GO on Playstation 4 internet connectivity Email issues Monopoly  credit after cancellation has not been received after more than a year  False Promises  Blocking UDP Port 443  Refuses to Schedule a Future Service Stoppage Overbilling  - failure to provide service, refusal to void contract Spotty  service without service despite willingness to pay Cable Modem rent for Internet access Speed issues AT&T Fraudulent claims reported to collections agency  using a Data Cap to take however much money they like  Data Cap Speed of service  data cap "trials"  billing problem  Needs Competition  services/billing issues Incorrect Bill Legality of data caps Data caps  Added Service After I Declined It  Misled With Overage Policy Cable service and telephone connect not complete  data cap  Won\'t Cancel My Service Data Caps  disconnecting service before due date  data cap Unbelievable Treatment Denial of  Business (Phone and internet) Service to my dental practice they are forcing me for my bank account information by suspending my services for no reason (I also feel like they are committing corporate theft).  discontinuation of service issue  customer service  bandwidth data caps in Atlanta, GA  won\'t quit charging me for modem rental  download caps Horrible  Customer Service Data Cap Bad Customer Service disconnection of service  Data Usage Charges  refuses service to my address  will not let me discuss my bill or service with a representative  billing frauds  TV/Internet hookup no service for 5+ days  - Billing  Internet  speed integrity Data cap  Atlanta Data Caps  Atlanta Data Caps  Poor Customer Service  bill  Data Cap Unfair Billing Practices  data caps  Refusing to Honor Internet Rate speed Not Acceptable Internet Additional Charge.  internet and cable service  deceptive advertising, overage charges  Data Caps  Support Unable to Provide Accurate Information  Data Usage Limits Repeated Erroneous Modem Rental Charge Xfinity pricing  monopoly Internet connection both upload and download speeds Internet Availability  "50 mb/s" speed and throttling  (Xfinity) Monopolistic Billing Practices Internet Throttling Data Usage Overage double billing after change of service Bandwidth Caps becoming excessive  data limits Unable to cancel xfinity home security  trying to setup stuff we didn\'t order Terrible waiting times Incorrect prices for new customers  is throttling my internet Internet Pricing MISC. CHARGES  throttles ...

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
tokens = word_tokenize(data)

# %%
tokens_without_sw = [word for word in tokens if not word in stopwords.words() and word.isalnum()]

# %%
tokens_without_sw = [word.lower() for word in tokens_without_sw]

# %%
len(tokens_without_sw)
# Out:
# 6682

# %%
freq=nltk.FreqDist(tokens_without_sw)

# %%
freq
# Out:
# FreqDist({'internet': 510, 'service': 429, 'billing': 273, 'data': 215, 'speed': 112, 'cap': 102, 'customer': 88, 'issues': 86, 'caps': 77, 'speeds': 70, ...})

# %%
freq.plot(20)

# %%
#so from here we can see that most of the complaints are related to the internet issues, then service issues then 
#billing issues and so on.
